# %% [markdown]
# ### Pandas
#
# We are going to use pandas to take a look at the super popular Titanic dataset. Pandas is an easy to use open source data analysis and manipulation tool, built on top of Python, specifically the Numpy package. Its key data structure is called the DataFrame. DataFrames allow you to store and manipulate data in a tabular form of rows and columns.

# %%
# import our libraries
# because pandas is built on numpy, you'll often need to perform numpy methods
# good practice to import both
import pandas as pd
import numpy as np

# %%
# import our csv and make a dataframe
# it's good to specify dtype
# here, we set it to object so that it can have mixed datatypes
df = pd.read_csv('data/titanic.csv', dtype=object)

# %%
# see the first 10 rows
df.head(10)
# Out:
#   pclass survived                                             name     sex  \
# 0      1        1                    Allen, Miss. Elisabeth Walton  female
# 1      1        1                   Allison, Master. Hudson Trevor    male
# 2      1        0                     Allison, Miss. Helen Loraine  female
# 3      1        0             Allison, Mr. Hudson Joshua Creighton    male
# 4      1        0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# 5      1        1                              Anderson, Mr. Harry    male
# 6      1        1                Andrews, Miss. Kornelia Theodosia  female
# 7      1        0                           Andrews, Mr. Thomas Jr    male
# 8      1        1    Appleton, Mrs. Edward Dale (Charlotte Lamson)  female
# 9      1        0                          Artagaveytia, Mr. Ramon    male
#
#       age sibsp parch    ticket      fare    cabin embarked boat body  \
# 0      29     0     0     24160  211.3375       B5        S    2  NaN
# ...

# %%
# and the last 10 rows
df.tail(10)
# Out:
#      pclass survived                                     name     sex   age  \
# 1300      3        1  Yasbeck, Mrs. Antoni (Selini Alexander)  female    15
# 1301      3        0                     Youseff, Mr. Gerious    male  45.5
# 1302      3        0                        Yousif, Mr. Wazli    male   NaN
# 1303      3        0                    Yousseff, Mr. Gerious    male   NaN
# 1304      3        0                     Zabour, Miss. Hileni  female  14.5
# 1305      3        0                    Zabour, Miss. Thamine  female   NaN
# 1306      3        0                Zakarian, Mr. Mapriededer    male  26.5
# 1307      3        0                      Zakarian, Mr. Ortin    male    27
# 1308      3        0                       Zimmerman, Mr. Leo    male    29
# 1309    NaN      NaN                                      NaN     NaN   NaN
#
#      sibsp parch  ticket     fare cabin embarked boat body home.dest
# ...

# %%
#see the data (jupyter notebook will not show all)
df
# Out:
#      pclass survived                                               name  \
# 0         1        1                      Allen, Miss. Elisabeth Walton
# 1         1        1                     Allison, Master. Hudson Trevor
# 2         1        0                       Allison, Miss. Helen Loraine
# 3         1        0               Allison, Mr. Hudson Joshua Creighton
# 4         1        0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5         1        1                                Anderson, Mr. Harry
# 6         1        1                  Andrews, Miss. Kornelia Theodosia
# 7         1        0                             Andrews, Mr. Thomas Jr
# 8         1        1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9         1        0                            Artagaveytia, Mr. Ramon
# 10        1        0                             Astor, Col. John Jacob
# 11        1        1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
# get all of our column headers in a list
list(df)
# Out:
# ['pclass',
#  'survived',
#  'name',
#  'sex',
#  'age',
#  'sibsp',
#  'parch',
#  'ticket',
#  'fare',
#  'cabin',
#  'embarked',
#  'boat',
#  'body',
#  'home.dest']

# %%
# check the size of our dataframe
# if you're ever trying to add dfs, it's important the shape matches 
df.shape
# Out:
# (1310, 14)

# %%
# see all rows
pd.set_option('display.max_rows', None) # (takes, pat and value) https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.set_option.html#pandas.set_option

# importing our csv again
df = pd.read_csv('data/titanic.csv', dtype=object)

# %%
df
# Out:
#      pclass survived                                               name  \
# 0         1        1                      Allen, Miss. Elisabeth Walton
# 1         1        1                     Allison, Master. Hudson Trevor
# 2         1        0                       Allison, Miss. Helen Loraine
# 3         1        0               Allison, Mr. Hudson Joshua Creighton
# 4         1        0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5         1        1                                Anderson, Mr. Harry
# 6         1        1                  Andrews, Miss. Kornelia Theodosia
# 7         1        0                             Andrews, Mr. Thomas Jr
# 8         1        1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9         1        0                            Artagaveytia, Mr. Ramon
# 10        1        0                             Astor, Col. John Jacob
# 11        1        1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
# let's drop the last row!
df = df.drop(df.index[1309])

# %%
df
# Out:
#      pclass survived                                               name  \
# 0         1        1                      Allen, Miss. Elisabeth Walton
# 1         1        1                     Allison, Master. Hudson Trevor
# 2         1        0                       Allison, Miss. Helen Loraine
# 3         1        0               Allison, Mr. Hudson Joshua Creighton
# 4         1        0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 5         1        1                                Anderson, Mr. Harry
# 6         1        1                  Andrews, Miss. Kornelia Theodosia
# 7         1        0                             Andrews, Mr. Thomas Jr
# 8         1        1      Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9         1        0                            Artagaveytia, Mr. Ramon
# 10        1        0                             Astor, Col. John Jacob
# 11        1        1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# ...

# %%
# create a dataframe called name_df with only the data that contain the name Allison
name_df = df[df['name'].str.contains('Allison')]

# %%
name_df
# Out:
#   pclass survived                                             name     sex  \
# 1      1        1                   Allison, Master. Hudson Trevor    male
# 2      1        0                     Allison, Miss. Helen Loraine  female
# 3      1        0             Allison, Mr. Hudson Joshua Creighton    male
# 4      1        0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age sibsp parch  ticket      fare    cabin embarked boat body  \
# 1  0.9167     1     2  113781  151.5500  C22 C26        S   11  NaN
# 2       2     1     2  113781  151.5500  C22 C26        S  NaN  NaN
# 3      30     1     2  113781  151.5500  C22 C26        S  NaN  135
# 4      25     1     2  113781  151.5500  C22 C26        S  NaN  NaN
#
#                          home.dest
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# the indices got messed up, let's clean it up!
# we drop the jumbled up indices and we update it with a new index numbering
name_df.reset_index(drop=True, inplace=True)

# %%
name_df
# Out:
#   pclass survived                                             name     sex  \
# 0      1        1                   Allison, Master. Hudson Trevor    male
# 1      1        0                     Allison, Miss. Helen Loraine  female
# 2      1        0             Allison, Mr. Hudson Joshua Creighton    male
# 3      1        0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age sibsp parch  ticket      fare    cabin embarked boat body  \
# 0  0.9167     1     2  113781  151.5500  C22 C26        S   11  NaN
# 1       2     1     2  113781  151.5500  C22 C26        S  NaN  NaN
# 2      30     1     2  113781  151.5500  C22 C26        S  NaN  135
# 3      25     1     2  113781  151.5500  C22 C26        S  NaN  NaN
#
#                          home.dest
# 0  Montreal, PQ / Chesterville, ON
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON

# %%
#let's say we want to look for 2nd class passengers where sex = female 
# this won't work and we'll see why 
second_female_df = df[(df['pclass'] == 2) & (df['sex'] == 'female')]

# %%
# empty df 
second_female_df
# Out:
# Empty DataFrame
# Columns: [pclass, survived, name, sex, age, sibsp, parch, ticket, fare, cabin, embarked, boat, body, home.dest]
# Index: []

# %%
# why? because the numbers in pclass are strings
df.iloc[0]['pclass']
# Out:
# '1'

# %%
# let's convert all strings to int for the column pclass
df['pclass'] = df['pclass'].astype(int)

# %%
# let's try that again
second_female_df = df[(df['pclass'] == 2) & (df['sex'] == 'female')]

# %%
second_female_df
# Out:
#      pclass survived                                               name  \
# 324       2        1              Abelson, Mrs. Samuel (Hannah Wizosky)
# 329       2        1  Angle, Mrs. William A (Florence "Mary" Agnes H...
# 333       2        1                            Ball, Mrs. (Ada E Hall)
# 337       2        1                  Beane, Mrs. Edward (Ethel Clarke)
# 340       2        1                        Becker, Miss. Marion Louise
# 341       2        1                       Becker, Miss. Ruth Elizabeth
# 342       2        1   Becker, Mrs. Allen Oliver (Nellie E Baumgardner)
# 344       2        1                            Bentham, Miss. Lilian W
# 349       2        1                      Brown, Miss. Amelia "Mildred"
# 350       2        1                          Brown, Miss. Edith Eileen
# 352       2        1  Brown, Mrs. Thomas William Solomon (Elizabeth ...
# 353       2        1                Bryhl, Miss. Dagmar Jenny Ingeborg
# ...

# %%
# reset indices
second_female_df.reset_index(drop=True, inplace=True)

# %%
second_female_df
# Out:
#      pclass survived                                               name  \
# 0         2        1              Abelson, Mrs. Samuel (Hannah Wizosky)
# 1         2        1  Angle, Mrs. William A (Florence "Mary" Agnes H...
# 2         2        1                            Ball, Mrs. (Ada E Hall)
# 3         2        1                  Beane, Mrs. Edward (Ethel Clarke)
# 4         2        1                        Becker, Miss. Marion Louise
# 5         2        1                       Becker, Miss. Ruth Elizabeth
# 6         2        1   Becker, Mrs. Allen Oliver (Nellie E Baumgardner)
# 7         2        1                            Bentham, Miss. Lilian W
# 8         2        1                      Brown, Miss. Amelia "Mildred"
# 9         2        1                          Brown, Miss. Edith Eileen
# 10        2        1  Brown, Mrs. Thomas William Solomon (Elizabeth ...
# 11        2        1                Bryhl, Miss. Dagmar Jenny Ingeborg
# ...

# %%
second_female_df.shape
# Out:
# (106, 14)

# %%
# let's import matplotlib and play around with our data!
import matplotlib.pyplot as plt

# %%
df['survived'].value_counts()
# Out:
# 0    809
# 1    500
# Name: survived, dtype: int64

# %%
# using axes plot - gives you more customization abilities
# dataframe.value_counts: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.value_counts.html#pandas.DataFrame.value_counts
ax = df['survived'].value_counts().plot(kind='bar', color=['c', 'y']) 
ax.set_xticklabels(['dead', 'survived'])
ax.set(ylabel='number of passengers')
ax.set(title='survival distribution')
plt.show()
